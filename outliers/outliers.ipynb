# %% [markdown]
# So, this is the code for Lesson 7: Outliers.
#
# Now, I want to make sure that this code can stand alone so I am going to run the starter code again and make sure I am starting with all the data clean and the variables in an unaltered state.

# %%
# %run outlier_removal_regression.py
# Out:
# your regression object doesn't exist, or isn't name reg
# can't make predictions to use in identifying outliers
# outlierCleaner() is returning an empty list, no refitting to be done

# %% [markdown]
# Now just to be sure that I don't have something messed up with the processing of the code I am going to go into the folder and see what other code there might be in there.

# %%
ls
# Out:
# enron_outliers.py                 outliers.ipynb
# outlier_cleaner.py                practice_outliers_ages.pkl
# outlier_cleaner.pyc               practice_outliers_net_worths.pkl
# outlier_removal_regression.py

# %%
ages_train[:3]
# Out:
# array([[57],
#        [57],
#        [34]])

# %% [markdown]
# Ok, so that looks good. Tbose look like ages to me. Now we run the code to create the outlier removal.

# %%
len(predictions)
# Out:
# 90

# %%
predictions[-5:]
# Out:
# array([[ 355.27551337],
#        [ 345.11965208],
#        [ 274.02862307],
#        [ 309.57413758],
#        [ 172.47001021]])

# %%
#!/usr/bin/python


def outlierCleaner(predictions, ages, net_worths):
    """
        Clean away the 10% of points that have the largest
        residual errors (difference between the prediction
        and the actual net worth).

        Return a list of tuples named cleaned_data where 
        each tuple is of the form (age, net_worth, error).
    """
    
    cleaned_data = []

    ### your code goes here


    for i in range(len(predictions)):
        cleaned_tuple = ()
        age_i = ages[i]
        net_worth_i = net_worths[i]
        error_i = (net_worths[i] - predictions[i])**2
        cleaned_tuple = (int(age_i), float(net_worth_i), float(error_i))
        cleaned_data.append(cleaned_tuple)
    

    cleaned_data = sorted(cleaned_data,key=lambda x: x[2])
    n = len(cleaned_data)/10
    cleaned_data = cleaned_data[:-n]

    

    return cleaned_data

# %%
myList = outlierCleaner(predictions, ages_train, net_worths_train)

# %%
#!/usr/bin/python

import random
import numpy
import matplotlib.pyplot as plt
import pickle

#from outlier_cleaner import outlierCleaner


### load up some practice data with outliers in it
ages = pickle.load( open("practice_outliers_ages.pkl", "r") )
net_worths = pickle.load( open("practice_outliers_net_worths.pkl", "r") )



### ages and net_worths need to be reshaped into 2D numpy arrays
### second argument of reshape command is a tuple of integers: (n_rows, n_columns)
### by convention, n_rows is the number of data points
### and n_columns is the number of features
ages       = numpy.reshape( numpy.array(ages), (len(ages), 1))
net_worths = numpy.reshape( numpy.array(net_worths), (len(net_worths), 1))
from sklearn.cross_validation import train_test_split
ages_train, ages_test, net_worths_train, net_worths_test = train_test_split(ages, net_worths, test_size=0.1, random_state=42)

### fill in a regression here!  Name the regression object reg so that
### the plotting code below works, and you can see what your regression looks like

from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(ages_train, net_worths_train)

# Now I calculate the r-squared
net_worths_test_pred = reg.predict(ages_test)
SSE = sum((net_worths_test_pred - net_worths_test)**2)

import numpy as np
 
mean = np.mean(net_worths_test)
TSS = sum((net_worths_test - mean)**2)

print "r_squared: ", 1 - SSE/TSS



### create the variables needed for outlier_cleaner



try:
    plt.plot(ages, reg.predict(ages), color="blue")
except NameError:
    pass
plt.scatter(ages, net_worths)
plt.show()


### identify and remove the most outlier-y points
cleaned_data = []
try:
    predictions = reg.predict(ages_train)
    cleaned_data = outlierCleaner( predictions, ages_train, net_worths_train )
except NameError:
    print "your regression object doesn't exist, or isn't name reg"
    print "can't make predictions to use in identifying outliers"



### only run this code if cleaned_data is returning data
if len(cleaned_data) > 0:
    ages, net_worths, errors = zip(*cleaned_data)
    ages       = numpy.reshape( numpy.array(ages), (len(ages), 1))
    net_worths = numpy.reshape( numpy.array(net_worths), (len(net_worths), 1))

    ### refit your cleaned data!
    try:
        reg.fit(ages, net_worths)
        plt.plot(ages, reg.predict(ages), color="blue")
    except NameError:
        print "you don't seem to have regression imported/created,"
        print "   or else your regression object isn't named reg"
        print "   either way, only draw the scatter plot of the cleaned data"
    plt.scatter(ages, net_worths)
    plt.xlabel("ages")
    plt.ylabel("net worths")
    plt.show()
    print reg.coef_[0]
    # Now I calculate the r-squared
    net_worths_test_pred = reg.predict(ages_test)
    SSE = sum((net_worths_test_pred - net_worths_test)**2)

    import numpy as np

    mean = np.mean(net_worths_test)
    TSS = sum((net_worths_test - mean)**2)

    print "r_squared: ", 1 - SSE/TSS

else:
    print "outlierCleaner() is returning an empty list, no refitting to be done"
# Out:
# r_squared:  [ 0.87826247]
# [ 6.36859481]
# r_squared:  [ 0.98318946]

# %%
pred = reg.predict(ages_test)

# %%
myList[0:][0]
# Out:
# (20, 96.75392597329417, 126.76863441444092)

# %%
ages, net_worths, errors = zip(*cleaned_data)

# %%
pred_test = reg.predict(ages_test)

# %%
ESS = sum((net_worths_test - pred_test)**2)

# %%
net_worths_test_mean = np.mean(net_worths_test)

# %%
TSS = sum((net_worths_test - net_worths_test_mean)**2)

# %%
1 - ESS / TSS
# Out:
# array([ 0.91650552])

# %%
## aborted attemt to find the R-squared after the data had been cleaned. Figured
## out that I should just add on to the starter code. 
ages, net_worths, errors = zip(*cleaned_data)

net_worths_series = np.asarray(net_worths)
ages_series = np.asarray(ages)

net_worths_series[:5]
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(ages_series, net_worths_series)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-364-7ade5dcb00ba> in <module>()
#       9 from sklearn import linear_model
#      10 reg = linear_model.LinearRegression()
# ---> 11 reg.fit(ages_series, net_worths_series)
#
# /Users/michaelreinhard/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, n_jobs)
#     353
#     354         X, y, X_mean, y_mean, X_std = self._center_data(
# --> 355             X, y, self.fit_intercept, self.normalize, self.copy_X)
#     356
#     357         if sp.issparse(X):
#
# /Users/michaelreinhard/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in center_data(X, y, fit_intercept, normalize, copy, sample_weight)
#     102                 X /= X_std
#     103             else:
# --> 104                 X_std = np.ones(X.shape[1])
# ...

# %% [markdown]
# **Enron Outliers Visualized**

# %%
# %run enron_outliers.py

# %%
# %cat enron_outliers.py
# Out:
# #!/usr/bin/python
#
# import pickle
# import sys
# import matplotlib.pyplot
# sys.path.append("../tools/")
# from feature_format import featureFormat, targetFeatureSplit
#
#
# ### read in data dictionary, convert to numpy array
# data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )
# features = ["salary", "bonus"]
# data = featureFormat(data_dict, features)
#
#
# ### your code below

# %%
#!/usr/bin/python

import pickle
import sys
import matplotlib.pyplot
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit


### read in data dictionary, convert to numpy array
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )
features = ["salary", "bonus"]
data_dict.pop('TOTAL',0)
data = featureFormat(data_dict, features)


### your code below

# %matplotlib inline

for point in data:
    salary = point[0]
    bonus = point[1]
    matplotlib.pyplot.scatter( salary, bonus )

matplotlib.pyplot.xlabel("salary")
matplotlib.pyplot.ylabel("bonus")
matplotlib.pyplot.show()

# %% [markdown]
# going to try to get the r-squared on the data after outliers have been removed.

# %%
len(net_worths_series)
# Out:
# 81

# %%
net_worths_series[:5]
# Out:
# array([ 177.46485913,  187.09760491,  173.54835439,  186.46155999,
#         271.75164335])

# %%
max(net_worths)
# Out:
# 424.5580423540415

# %%
data_dict
# Out:
# {'ALLEN PHILLIP K': {'bonus': 4175000,
#   'deferral_payments': 2869717,
#   'deferred_income': -3081055,
#   'director_fees': 'NaN',
#   'email_address': 'phillip.allen@enron.com',
#   'exercised_stock_options': 1729541,
#   'expenses': 13868,
#   'from_messages': 2195,
#   'from_poi_to_this_person': 47,
#   'from_this_person_to_poi': 65,
#   'loan_advances': 'NaN',
#   'long_term_incentive': 304805,
#   'other': 152,
#   'poi': False,
#   'restricted_stock': 126027,
#   'restricted_stock_deferred': -126027,
#   'salary': 201955,
#   'shared_receipt_with_poi': 1407,
#   'to_messages': 2902,
#   'total_payments': 4484442,
#   'total_stock_value': 1729541},
#  'BADUM JAMES P': {'bonus': 'NaN',
#   'deferral_payments': 178980,
#   'deferred_income': 'NaN',
#   'director_fees': 'NaN',
#   'email_address': 'NaN',
#   'exercised_stock_options': 257817,
#   'expenses': 3486,
#   'from_messages': 'NaN',
#   'from_poi_to_this_person': 'NaN',
#   'from_this_person_to_poi': 'NaN',
# ...

# %%
names = {}
for name in data_dict:
    names[name] = data_dict[name]['bonus']

# %%
names
# Out:
# {'ALLEN PHILLIP K': 4175000,
#  'BADUM JAMES P': 'NaN',
#  'BANNANTINE JAMES M': 'NaN',
#  'BAXTER JOHN C': 1200000,
#  'BAY FRANKLIN R': 400000,
#  'BAZELIDES PHILIP J': 'NaN',
#  'BECK SALLY W': 700000,
#  'BELDEN TIMOTHY N': 5249999,
#  'BELFER ROBERT': 'NaN',
#  'BERBERIAN DAVID': 'NaN',
#  'BERGSIEKER RICHARD P': 250000,
#  'BHATNAGAR SANJAY': 'NaN',
#  'BIBI PHILIPPE A': 1000000,
#  'BLACHMAN JEREMY M': 850000,
#  'BLAKE JR. NORMAN P': 'NaN',
#  'BOWEN JR RAYMOND M': 1350000,
#  'BROWN MICHAEL': 'NaN',
#  'BUCHANAN HAROLD G': 500000,
#  'BUTTS ROBERT H': 750000,
#  'BUY RICHARD B': 900000,
#  'CALGER CHRISTOPHER F': 1250000,
#  'CARTER REBECCA C': 300000,
#  'CAUSEY RICHARD A': 1000000,
#  'CHAN RONNIE': 'NaN',
#  'CHRISTODOULOU DIOMEDES': 'NaN',
#  'CLINE KENNETH W': 'NaN',
#  'COLWELL WESLEY': 1200000,
#  'CORDES WILLIAM R': 'NaN',
#  'COX DAVID': 800000,
#  'CUMBERLAND MICHAEL S': 325000,
#  'DEFFNER JOSEPH M': 600000,
#  'DELAINEY DAVID W': 3000000,
# ...

# %%
inverse = [(value, key) for key, value in names.items()]
print max(inverse)[0]
# Out:
# NaN

# %%
max(names.values())
# Out:
# 'NaN'

# %%
seq = [x for x in names.values() if not isinstance(x, str)]
print max(seq)
# Out:
# 97343619

# %%
[k for k, v in names.iteritems() if v == 97343619]
# Out:
# ['TOTAL']

# %%
sorted(names, key=names.get)
# Out:
# ['DODSON KEITH',
#  'SULLIVAN-SHAKLOVITZ COLLEEN',
#  'REYNOLDS LAWRENCE',
#  'ECHOLS JOHN B',
#  'SHELBY REX',
#  'LINDHOLM TOD A',
#  'JACKSON CHARLENE R',
#  'BERGSIEKER RICHARD P',
#  'PICKERING MARK R',
#  'CARTER REBECCA C',
#  'TILNEY ELIZABETH A',
#  'MORDAUNT KRISTINA M',
#  'CUMBERLAND MICHAEL S',
#  'WASAFF GEORGE',
#  'ELLIOTT STEVEN',
#  'FITZGERALD JAY L',
#  'PIPER GREGORY F',
#  'KAMINSKI WINCENTY J',
#  'MURRAY JULIA H',
#  'BAY FRANKLIN R',
#  'DETMERING TIMOTHY J',
#  'WHITE JR THOMAS E',
#  'STABLER FRANK',
#  'BUCHANAN HAROLD G',
#  'GAHN ROBERT S',
#  'METTS MARK',
#  'DEFFNER JOSEPH M',
#  'SHARP VICTORIA T',
#  'DIETRICH JANET R',
#  'TAYLOR MITCHELL S',
#  'GLISAN JR BEN F',
#  'SHAPIRO RICHARD S',
#  'SUNDE MARTIN',
#  'RIEKER PAULA H',
#  'BECK SALLY W',
#  'HERMANN ROBERT J',
#  'KOENIG MARK E',
#  'GOLD JOSEPH',
#  'BUTTS ROBERT H',
#  'OLSON CINDY K',
#  'DURAN WILLIAM D',
#  'UMANOFF ADAM S',
#  'KOPPER MICHAEL J',
#  'COX DAVID',
# ...

# %%
items = data_dict.items()
items.sort(key=lambda item: (item[1], item[0]))
sorted_keys = [ item[0] for item in items ]

# %%
sorted_keys
# Out:
# ['DODSON KEITH',
#  'REYNOLDS LAWRENCE',
#  'SULLIVAN-SHAKLOVITZ COLLEEN',
#  'LINDHOLM TOD A',
#  'SHELBY REX',
#  'ECHOLS JOHN B',
#  'BERGSIEKER RICHARD P',
#  'JACKSON CHARLENE R',
#  'TILNEY ELIZABETH A',
#  'CARTER REBECCA C',
#  'PICKERING MARK R',
#  'WASAFF GEORGE',
#  'CUMBERLAND MICHAEL S',
#  'MORDAUNT KRISTINA M',
#  'ELLIOTT STEVEN',
#  'FITZGERALD JAY L',
#  'BAY FRANKLIN R',
#  'PIPER GREGORY F',
#  'MURRAY JULIA H',
#  'KAMINSKI WINCENTY J',
#  'DETMERING TIMOTHY J',
#  'WHITE JR THOMAS E',
#  'STABLER FRANK',
#  'BUCHANAN HAROLD G',
#  'GAHN ROBERT S',
#  'SHARP VICTORIA T',
#  'TAYLOR MITCHELL S',
#  'GLISAN JR BEN F',
#  'DIETRICH JANET R',
#  'DEFFNER JOSEPH M',
#  'METTS MARK',
#  'SHAPIRO RICHARD S',
#  'RIEKER PAULA H',
#  'HERMANN ROBERT J',
#  'KOENIG MARK E',
#  'SUNDE MARTIN',
#  'BECK SALLY W',
#  'OLSON CINDY K',
#  'BUTTS ROBERT H',
#  'GOLD JOSEPH',
#  'DURAN WILLIAM D',
#  'UMANOFF ADAM S',
#  'DERRICK JR. JAMES V',
#  'DONAHUE JR JEFFREY M',
# ...

# %%
data_dict['YEAGER F SCOTT']
# Out:
# {'bonus': 'NaN',
#  'deferral_payments': 'NaN',
#  'deferred_income': 'NaN',
#  'director_fees': 'NaN',
#  'email_address': 'scott.yeager@enron.com',
#  'exercised_stock_options': 8308552,
#  'expenses': 53947,
#  'from_messages': 'NaN',
#  'from_poi_to_this_person': 'NaN',
#  'from_this_person_to_poi': 'NaN',
#  'loan_advances': 'NaN',
#  'long_term_incentive': 'NaN',
#  'other': 147950,
#  'poi': True,
#  'restricted_stock': 3576206,
#  'restricted_stock_deferred': 'NaN',
#  'salary': 158403,
#  'shared_receipt_with_poi': 'NaN',
#  'to_messages': 'NaN',
#  'total_payments': 360300,
#  'total_stock_value': 11884758}

# %%
for key in data_dict:
    if data_dict[key]['bonus']=='NaN' or data_dict[key]['bonus']=='NaN':
        continue
    if data_dict[key]['bonus']>5000000 and data_dict[key]['salary']>1000000:
        print key
    else: 
        print "no"
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# LAY KENNETH L
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# SKILLING JEFFREY K
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no

# %%
data_dict['MEYER ROCKFORD G']
# Out:
# {'bonus': 'NaN',
#  'deferral_payments': 1848227,
#  'deferred_income': 'NaN',
#  'director_fees': 'NaN',
#  'email_address': 'rockford.meyer@enron.com',
#  'exercised_stock_options': 493489,
#  'expenses': 'NaN',
#  'from_messages': 28,
#  'from_poi_to_this_person': 0,
#  'from_this_person_to_poi': 0,
#  'loan_advances': 'NaN',
#  'long_term_incentive': 'NaN',
#  'other': 'NaN',
#  'poi': False,
#  'restricted_stock': 462384,
#  'restricted_stock_deferred': 'NaN',
#  'salary': 'NaN',
#  'shared_receipt_with_poi': 22,
#  'to_messages': 232,
#  'total_payments': 1848227,
#  'total_stock_value': 955873}
